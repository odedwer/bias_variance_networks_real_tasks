# %%
# Run saliency entropy computations and print results
from model_analysis import model_analysis_obj, compute_models_entropy_stats

self.compute_saliency_maps(img_idx)

per_model_entropies, per_model_means, overall_mean, overall_var = compute_models_entropy_stats(model_analysis_obj, show_progress=True)

print("Per-model means:", per_model_means)
print("Overall mean:", overall_mean)
print("Overall variance:", overall_var)

import pprint
pprint.pprint(per_model_entropies)
